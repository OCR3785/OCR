# %%
# libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
df= pd.read_excel(r'C:\Users\orlik\Downloads\tasks\score.xlsx')

# %%
df. head (10)
# Out:
#    Column1  birth  gender                                         employment  \
# 0        0   1977  Female                     Full-time student or homemaker
# 1        1   1990  Female                     Full-time student or homemaker
# 2        2   1959    Male  Employed full time (or self-employed), 30 or m...
# 3        3   1995    Male    Employed part-time, less than 30 hours per week
# 4        4   1958  Female                                            Retired
# 5        5   1983  Female    Employed part-time, less than 30 hours per week
# 6        6   1968    Male  Employed full time (or self-employed), 30 or m...
# 7        7   1964  Female  Employed full time (or self-employed), 30 or m...
# 8        8   1951    Male    Employed part-time, less than 30 hours per week
# 9        9   1971  Female                     Full-time student or homemaker
#
#    pos1  neg1  pos2  neg2  pos3  neg3  ...  pos11  neg11  pos12  neg12  pos13  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...    3.0    3.0    2.0    3.0    3.0
# 1   3.0   2.0   2.0   2.0   3.0   2.0  ...    NaN    NaN    NaN    NaN    NaN
# 2   5.0   2.0   4.0   4.0   4.0   1.0  ...    NaN    NaN    NaN    NaN    NaN
# 3   4.0   2.0   4.0   4.0   4.0   4.0  ...    NaN    NaN    NaN    NaN    NaN
# 4   2.0   1.0   1.0   1.0   1.0   5.0  ...    NaN    NaN    NaN    NaN    NaN
# 5   NaN   NaN   NaN   NaN   NaN   NaN  ...    3.0    2.0    4.0    5.0    1.0
# 6   NaN   NaN   NaN   NaN   NaN   NaN  ...    2.0    4.0    2.0    4.0    3.0
# 7   3.0   1.0   1.0   1.0   2.0   1.0  ...    NaN    NaN    NaN    NaN    NaN
# 8   4.0   2.0   3.0   4.0   3.0   3.0  ...    NaN    NaN    NaN    NaN    NaN
# 9   4.0   2.0   3.0   4.0   4.0   4.0  ...    NaN    NaN    NaN    NaN    NaN
#
#    neg13    country  age  imcome   weights
# 0    3.0  Australia   45     Low  0.910536
# 1    NaN  Australia   32     Low  0.901440
# 2    NaN  Australia   63    High  1.643108
# 3    NaN  Australia   27     Med  0.710450
# 4    NaN  Australia   64     Low  0.992758
# 5    1.0  Australia   39     Med  0.713358
# 6    2.0  Australia   54     Med  0.717619
# 7    NaN  Australia   58    High  1.633353
# 8    NaN  Australia   71     Med  0.782421
# 9    NaN  Australia   51     Med  0.713358
#
# [10 rows x 34 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA

# Load 
df= pd.read_excel(r'C:\Users\orlik\Downloads\tasks\score.xlsx')

# Select variables
columns = ["pos1", "pos2", "pos3", "pos4", "pos5", "pos6", "pos7", "pos8", "pos9", "pos10", "pos11", "pos12", "pos13", "neg1", "neg2", "neg3", "neg4", "neg5", "neg6", "neg7", "neg8", "neg9", "neg10", "neg11", "neg12", "neg13"]
df = df[columns]

# Impute the missing values with the mean of the column
imputer = SimpleImputer(strategy='mean')
df_imputed = imputer.fit_transform(df)

# PCA
pca = PCA()
pca.fit(df_imputed)


# Plot the explained variance ratio for each component
plt.bar(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_)
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance Ratio")
plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.18306757, 0.17310894, 0.08703154, 0.06807049, 0.04177091,
#        0.04065019, 0.0323642 , 0.02807281, 0.02633231, 0.02611843,
#        0.02349306, 0.02215153, 0.0216552 , 0.02047618, 0.01981899,
#        0.0194365 , 0.0193052 , 0.01833788, 0.01759459, 0.01747897,
#        0.01689085, 0.01616729, 0.01564507, 0.01547631, 0.01479481,
#        0.01469017])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 pca == min(n_samples, n_features)
#
# NameError: name 'n_samples' is not defined

# %%
pca = PCA(4)
pca.fit(df_imputed)
# Out:
# PCA(n_components=4)

# %%
# Plot the explained variance for the questions selected
plt.bar(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_)
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance Ratio")
plt.show()
